# %%
# Import Dependencies 
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.manifold import TSNE

# %%
#  Import and read the csv

school_df = pd.read_csv("../Resources/both_b_c_exiting.csv")
school_df.head()
# Out:
# C:\Users\Tech\anaconda3\envs\pythondata\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (22,23,25,26,27,28,29,30,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   School Year    State                                          Exit Code  \
# 0   2015-2016  Alabama                                               Died
# 1   2015-2016  Alabama                                        Dropped out
# 2   2015-2016  Alabama  Graduated with a regular high school diploma a...
# 3   2015-2016  Alabama         Graduated with regular high school diploma
# 4   2015-2016  Alabama                      Moved, known to be continuing
#
#          Disability Age 14 Age 15 Age 16 Age 17 Age 18 Age 19  ...  \
# 0  All Disabilities      0      4      3      3      3      2  ...
# 1  All Disabilities      -      -     52    130     98     24  ...
# ...

# %%
school_df.columns
# Out:
# Index(['School Year', 'State', 'Exit Code', 'Disability', 'Age 14', 'Age 15',
#        'Age 16', 'Age 17', 'Age 18', 'Age 19', 'Age 20', 'Age 21',
#        'Age 14 to 21 total', 'Hispanic/Latino',
#        'American Indian or Alaska Native', 'Asian',
#        'Black or African American',
#        'Native Hawaiian or Other Pacific Islander', 'White',
#        'Two or more races', 'Male', 'Female', 'Limited English proficiency',
#        'Non-limited English proficiency', 'filename', 'Year',
#        'Reporting Period', 'Ages Birth through 2', 'Two or More Races',
#        'R/E Total', 'Gender Total', 'English learner', 'Non-English learner'],
#       dtype='object')

# %%
reduced_df = school_df[["School Year","State", "Exit Code", "Disability", "Age 14", "Age 15", "Age 16", "Age 17", "Age 18", "Age 19", "Age 20", "Age 21", "Hispanic/Latino", "American Indian or Alaska Native", "Asian", "Black or African American", "Native Hawaiian or Other Pacific Islander", "White", "Female","Year"]]
reduced_df.head()
# Out:
#   School Year    State                                          Exit Code  \
# 0   2015-2016  Alabama                                               Died
# 1   2015-2016  Alabama                                        Dropped out
# 2   2015-2016  Alabama  Graduated with a regular high school diploma a...
# 3   2015-2016  Alabama         Graduated with regular high school diploma
# 4   2015-2016  Alabama                      Moved, known to be continuing
#
#          Disability Age 14 Age 15 Age 16 Age 17 Age 18 Age 19 Age 20 Age 21  \
# 0  All Disabilities      0      4      3      3      3      2      1      0
# 1  All Disabilities      -      -     52    130     98     24     12      1
# 2  All Disabilities      0      0     11   1457   2114    440    184     34
# 3  All Disabilities      -      -     11   1427   2058    419    122     22
# 4  All Disabilities    407    470    498    367    170     56     30      4
#
#   Hispanic/Latino American Indian or Alaska Native Asian  \
# ...

# %%
for column in reduced_df.columns:
    print(f"column {column} have {reduced_df[column].isnull().sum()} null values")
# Out:
# column School Year have 3135 null values
# column State have 0 null values
# column Exit Code have 0 null values
# column Disability have 3135 null values
# column Age 14 have 3135 null values
# column Age 15 have 3135 null values
# column Age 16 have 3135 null values
# column Age 17 have 3135 null values
# column Age 18 have 3135 null values
# column Age 19 have 3135 null values
# column Age 20 have 3135 null values
# column Age 21 have 3135 null values
# column Hispanic/Latino have 0 null values
# column American Indian or Alaska Native have 0 null values
# column Asian have 0 null values
# column Black or African American have 0 null values
# column Native Hawaiian or Other Pacific Islander have 0 null values
# column White have 0 null values
# column Female have 0 null values
# column Year have 39650 null values

# %%
reduced_df.head()
# Out:
#   School Year    State                                          Exit Code  \
# 0   2015-2016  Alabama                                               Died
# 1   2015-2016  Alabama                                        Dropped out
# 2   2015-2016  Alabama  Graduated with a regular high school diploma a...
# 3   2015-2016  Alabama         Graduated with regular high school diploma
# 4   2015-2016  Alabama                      Moved, known to be continuing
#
#          Disability Age 14 Age 15 Age 16 Age 17 Age 18 Age 19 Age 20 Age 21  \
# 0  All Disabilities      0      4      3      3      3      2      1      0
# 1  All Disabilities      -      -     52    130     98     24     12      1
# 2  All Disabilities      0      0     11   1457   2114    440    184     34
# 3  All Disabilities      -      -     11   1427   2058    419    122     22
# 4  All Disabilities    407    470    498    367    170     56     30      4
#
#   Hispanic/Latino American Indian or Alaska Native Asian  \
# ...

# %%
reduced_df = reduced_df.(columns(Yeardropna()

# %%
for column in reduced_df.columns:
    print(f"column {column} have {reduced_df[column].isnull().sum()} null values")
# Out:
# column School Year have 0 null values
# column State have 0 null values
# column Exit Code have 0 null values
# column Disability have 0 null values
# column Age 14 have 0 null values
# column Age 15 have 0 null values
# column Age 16 have 0 null values
# column Age 17 have 0 null values
# column Age 18 have 0 null values
# column Age 19 have 0 null values
# column Age 20 have 0 null values
# column Age 21 have 0 null values
# column Hispanic/Latino have 0 null values
# column American Indian or Alaska Native have 0 null values
# column Asian have 0 null values
# column Black or African American have 0 null values
# column Native Hawaiian or Other Pacific Islander have 0 null values
# column White have 0 null values
# column Female have 0 null values
# column Year have 0 null values

# %%
reduced_df.head()
# Out:
# Empty DataFrame
# Columns: [School Year, State, Exit Code, Disability, Age 14, Age 15, Age 16, Age 17, Age 18, Age 19, Age 20, Age 21, Hispanic/Latino, American Indian or Alaska Native, Asian, Black or African American, Native Hawaiian or Other Pacific Islander, White, Female, Year]
# Index: []

# %%
reduced_df.count()
# Out:
# School Year                                  0
# State                                        0
# Exit Code                                    0
# Disability                                   0
# Age 14                                       0
# Age 15                                       0
# Age 16                                       0
# Age 17                                       0
# Age 18                                       0
# Age 19                                       0
# Age 20                                       0
# Age 21                                       0
# Hispanic/Latino                              0
# American Indian or Alaska Native             0
# Asian                                        0
# Black or African American                    0
# Native Hawaiian or Other Pacific Islander    0
# White                                        0
# Female                                       0
# Year                                         0
# dtype: int64
